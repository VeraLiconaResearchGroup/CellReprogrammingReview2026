# %% [markdown]
# **Author:** Paola Vera-Licona (Vera-Licona Research Group, University of Connecticut School of Medicine)
#
# # Figure 2 — modality UpSet plot
#
# Writes `figure2/Fig2_modality_upset.{pdf,png,tiff}`.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('.')))
from _repo_utils import run_script

run_script('figure2/fig2_modality_upset.py')
