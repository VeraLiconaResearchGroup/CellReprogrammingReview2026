# %% [markdown]
# **Authors:** Martha Vera Licona; Paola Vera-Licona (Vera-Licona Research Group, University of Connecticut School of Medicine)
#
# # Supporting Information S4 — dataset reuse table
#
# Builds `dataset_reuse/SI_4_DatasetReuse.xlsx` from CSVs in `dataset_reuse/data/`.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('.')))
from _repo_utils import run_script

run_script('dataset_reuse/build_si_4_xlsx.py')
