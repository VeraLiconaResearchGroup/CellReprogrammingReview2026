# %% [markdown]
# # Figure 3 — reproducibility audit
#
# Reads `data/SI_3_ReproducibilityAudit.xlsx` and writes `figure3/Fig3_reproducibility.{pdf,png,tiff}`.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('.')))
from _repo_utils import run_script

run_script('figure3/fig3_reproducibility.py')
