# %% [markdown]
# # Run all offline reproduction steps
#
# Regenerates **Figure 2**, **Figure 3**, and **Supporting Information S4** from bundled data. No network access required.
#
# Run this notebook top-to-bottom, or use `docker compose run --rm run-offline`.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('.')))
from _repo_utils import repo_root, run_script

repo_root()

# %%
run_script('figure3/fig3_reproducibility.py')

# %%
run_script('figure2/fig2_modality_upset.py')

# %%
run_script('dataset_reuse/build_si_4_xlsx.py')

# %% [markdown]
# Outputs are written next to each script (see repository README).
